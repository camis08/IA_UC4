# %% [markdown]
# <a href="https://colab.research.google.com/github/camis08/IA_UC4/blob/main/UC4_Aula2_estatistica_media_mediana_moda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 2 – Média, Mediana, Moda e Média Ponderada
#
# ## UC4 – Estatística aplicada à Inteligência Artificial
#
# ### Objetivos da aula
# - Conceituar com clareza média, mediana, moda e média ponderada
# - Entender quando cada medida faz mais sentido
# - Comparar as medidas em diferentes contextos
# - Resolver muitos exercícios, do básico ao aplicado
# - Relacionar essas medidas com análise de dados e Inteligência Artificial

# %% [markdown]
# ## Roteiro da aula
#
# 1. Revisão rápida: o que é uma medida de tendência central
# 2. Média aritmética simples
# 3. Mediana
# 4. Moda
# 5. Média ponderada
# 6. Comparação entre as medidas
# 7. Efeito dos valores extremos
# 8. Exemplos aplicados
# 9. Lista grande de exercícios
# 10. Desafio final

# %% [markdown]
# ## 1. O que são medidas de tendência central?
#
# Medidas de tendência central são valores que tentam representar o "centro" de um conjunto de dados.
#
# Elas ajudam a resumir informações.
#
# Exemplos:
# - qual é a nota típica de uma turma?
# - qual é o salário típico de um grupo?
# - qual tamanho de camiseta aparece com mais frequência?
# - qual foi, em média, a quantidade vendida por dia?
#
# As principais medidas de tendência central são:
# - **média**
# - **mediana**
# - **moda**
#
# Nesta aula, também veremos a **média ponderada**, que é muito importante em contextos escolares, indicadores e análise de dados.

# %% [markdown]
# Outras médias: Geométrica, Harmônica, Trunca, Ponto Médio e Winsorized.

# %%
"""
Geométrica

Calculada através da raiz enésima do produto de termos
ideal para conjuntos de dados que seguem uma progressão geométrica, taxas de crescimento, índices normalizados ou proporções
"""
# Out:
# '\nGeométrica\n\nCalculada através da raiz enésima do produto de termos\nideal para conjuntos de dados que seguem uma progressão geométrica, taxas de crescimento, índices normalizados ou proporções\n'

# %%
"""
Harmônica

Utilizada para calcular a média de taxas ou razões, sendo o inverso da média aritmética dos inversos dos números
É indicada para situações como velocidades médias (ida e volta) ou tempo de trabalho
"""
# Out:
# '\nHarmônica\n\nUtilizada para calcular a média de taxas ou razões, sendo o inverso da média aritmética dos inversos dos números\nÉ indicada para situações como velocidades médias (ida e volta) ou tempo de trabalho\n'

# %%
"""
Trunca

Esta média reduz o efeito de outliers (valores muito extremos) removendo uma
porcentagem específica dos dados menores e maiores antes de calcular a média aritmética simples
"""
# Out:
# '\nTrunca\n\nEsta média reduz o efeito de outliers (valores muito extremos) removendo uma\nporcentagem específica dos dados menores e maiores antes de calcular a média aritmética simples\n'

# %%
"""
Ponto Médio

É a média aritmética entre o valor máximo e o valor mínimo de um conjunto de dados
Representa o centro geométrico da amplitude dos dados
"""
# Out:
# '\nPonto Médio\n\nÉ a média aritmética entre o valor máximo e o valor mínimo de um conjunto de dados\nRepresenta o centro geométrico da amplitude dos dados\n'

# %%
"""
Winsorized

Similar à média truncada, mas em vez de remover os valores extremos, ela os substitui pelo valor mais próximo não removido
"""
# Out:
# '\nWinsorized\n\nSimilar à média truncada, mas em vez de remover os valores extremos, ela os substitui pelo valor mais próximo não removido\n'

# %%
salario1 = [2000,2000,5000,20000,100000]
salario2 = [2000,2000,5000,20000,20000]

# %%
media1 = sum(salario1)/len(salario1)
media1
# Out:
# 25800.0

# %%
media2 = sum(salario2)/len(salario2)
media2
# Out:
# 9800.0

# %% [markdown]
# ## 2. Média aritmética simples
#
# A média aritmética simples é a soma de todos os valores dividida pela quantidade de valores.
#
# ### Fórmula
#
# $$
# \bar{x} = \frac{x_1 + x_2 + x_3 + \dots + x_n}{n}
# $$
#
# ### Ideia intuitiva
# A média tenta "equilibrar" os dados.

# %% [markdown]
# ### Exemplo 1
# Notas: 6, 8 e 10
#
# $$
# \text{média} = \frac{6 + 8 + 10}{3} = \frac{24}{3} = 8
# $$
#
# Logo, a média é 8.

# %%
notas = [6,8,10]

# %%
#cALCULANDO MÉDIA COM PYTHON
media = sum(notas)/len(notas)
media
# Out:
# 8.0

# %%
#cALCULANDO MÉDIA COM NUMPY
import numpy as np
np.mean(notas)
# Out:
# np.float64(8.0)

# %%
#cALCULANDO MÉDIA COM STATISTICS
import statistics
statistics.mean(notas)
# Out:
# 8

# %% [markdown]
# ### Exemplo 2
# Idades: 18, 20, 22, 24, 26
#
# $$
# \text{média} = \frac{18+20+22+24+26}{5} = \frac{110}{5} = 22
# $$
#
# A média é 22.

# %%
idades = [18,22,20,24,26]
statistics.mean(idades)
# Out:
# 22

# %% [markdown]
# ### Quando a média é útil?
# A média é útil quando queremos um valor representativo geral e quando os dados não têm valores extremos muito distorcidos.

# %% [markdown]
# ### Exercício
#
# Calcule a média aritmética do "EXEMPLO 2" utilizando python, numpy e statistics

# %%
idades = [18,22,20,24,26]

# %%
statistics.mean(idades)
# Out:
# 22

# %%
np.mean(idades)
# Out:
# np.float64(22.0)

# %%
sum(idades)/len(idades)
# Out:
# 22.0

# %% [markdown]
# ## 3. Mediana
#
# A mediana é o valor que fica no meio dos dados **depois que eles são colocados em ordem**.

# %% [markdown]
# ### Passo a passo
# 1. Ordenar os dados
# 2. Verificar a quantidade de elementos
# 3. Encontrar o valor central
#
# ### Caso 1: quantidade ímpar de dados
# Exemplo: 3, 5, 8, 10, 12
#
# O valor do meio é 8.
# Logo, a mediana é 8.
#
# ### Caso 2: quantidade par de dados
# Exemplo: 4, 6, 8, 10
#
# Os dois valores centrais são 6 e 8.
# A mediana será a média entre eles:
#
# $$
# \text{mediana} = \frac{6+8}{2}=7
# $$

# %%
num = [4,6,8,10]
np.median(num)
# Out:
# np.float64(7.0)

# %%
statistics.median(num)
# Out:
# 7.0

# %% [markdown]
# ### Fórmula para encontrar a média quando o número de elementos (n) é impar:
#
#
# $$Md ={\left(\frac{n+1}{2}\right)}$$

# %% [markdown]
# ### Fórmula para encontrar a média quando o número de elementos (n) é impar:
#
# $$Md = \frac{{\left(\frac{n}{2}\right)} + {\left(\frac{n}{2} + 1\right)}}{2}$$

# %% [markdown]
# ### Exercício:
#
# Crie um código python para calcular a mediana (sem utilizar bibliotecas externas, como numpy, stati, etc)
#
# dica: para ordenar os dados, utilize ``dados ordenados = sorted(dados)``

# %%
"""
lista = [1,5,9,4,2,8]
lista_ordenada = sorted(lista)
lista_ordenada
"""
# Out:
# '\nlista = [1,5,9,4,2,8]\nlista_ordenada = sorted(lista)\nlista_ordenada\n'

# %%
"""
dados = [1,5,7,2,3,4,1]
dados_ordenados = sorted(dados)
dados_ordenados

n = len(dados_ordenados)
n

if n % 2 != 0:
    meio = n // 2 # // garantir divisão INTEIRA
    mediana = dados_ordenados[meio]
else:
    indice2 = n // 2
    indice1 = indice2 - 1
    mediana = (dados_ordenados[indice1] + dados_ordenados[indice2]) / 2


[1, 1, 2, 3, 4, 5, 7] -> ímpar + 1 = 7 / 2 = 3
"""
# Out:
# '\ndados = [1,5,7,2,3,4,1]\ndados_ordenados = sorted(dados)\ndados_ordenados\n\nn = len(dados_ordenados)\nn\n\nif n % 2 != 0:\n    meio = n // 2 # // garantir divisão INTEIRA\n    mediana = dados_ordenados[meio]\nelse:\n    indice2 = n // 2\n    indice1 = indice2 - 1\n    mediana = (dados_ordenados[indice1] + dados_ordenados[indice2]) / 2\n\n\n[1, 1, 2, 3, 4, 5, 7] -> ímpar + 1 = 7 / 2 = 3\n'

# %%
def calcular_mediana(dados):
    dados_ordenados = sorted(dados)
    n = len(dados_ordenados)

    if n == 0:
        return None #lista vazia

    #número ímpar
    if n % 2 != 0:
        meio = n // 2 # // garantir divisão INTEIRA
        mediana = dados_ordenados[meio]

    #número par
    else:
        indice2 = n // 2
        indice1 = indice2 - 1
        mediana = (dados_ordenados[indice1] + dados_ordenados[indice2]) / 2
    return mediana

lista1 = [2,4,8,10]
lista2 = [-1,10,20,18,40]
calcular_mediana(lista1)
# Out:
# 6.0

# %%
calcular_mediana(lista2)
# Out:
# 18

# %%
lista1.sort()
lista1
# Out:
# [2, 4, 8, 10]

# %%
lista2.sort()
lista2
# Out:
# [-1, 10, 18, 20, 40]

# %%
"""
if n % 2 == 0:
    print("par")
else:
    print("impar")
"""
# Out:
# '\nif n % 2 == 0:\n    print("par")\nelse:\n    print("impar")\n'

# %%
"""
import random
lista = [random.randint(1, 100) for _ in range(10)]
lista_ordenada = sorted(lista)
lista_ordenada
"""
# Out:
# '\nimport random\nlista = [random.randint(1, 100) for _ in range(10)]\nlista_ordenada = sorted(lista)\nlista_ordenada\n'

# %% [markdown]
# Utilizando o numpy e statistics:

# %%
mediana1 = np.median(lista1)
mediana2 = np.median(lista2)

mediana1,mediana2
# Out:
# (np.float64(6.0), np.float64(18.0))

# %%
mediana3 = statistics.median(lista1)
mediana4 = statistics.median(lista2)

mediana3,mediana4
# Out:
# (6.0, 18)

# %% [markdown]
# ### Por que a mediana é importante?
# A mediana é muito útil quando há valores extremos.
#
# Exemplo:
# Salários: 1800, 1900, 2000, 2100, 50000
#
# A média sobe muito por causa do 50000, mas a mediana continua mais próxima da realidade do grupo.

# %%
salarios = [1800, 1900, 2000, 2100, 50000]
mediana =  statistics.median(salarios)
media = statistics.mean(salarios)
print(f"A média é: {media} e a mediana é: {mediana}")
# Out:
# A média é: 11560 e a mediana é: 2000

# %%
salarios2 = [1800, 1900, 2000, 2100, 2100 ] # trasformo os 50000 em 2100
mediana =  statistics.median(salarios2)
media = statistics.mean(salarios2)
print(f"A média é: {media} e a mediana é: {mediana}")
# Out:
# A média é: 1980 e a mediana é: 2000

# %%
salarios3 = [1800, 1900, 2000, 2100] # tiro os 50000 que tansformei em 2100
mediana =  statistics.median(salarios3)
media = statistics.mean(salarios3)
print(f"A média é: {media} e a mediana é: {mediana}")
# Out:
# A média é: 1950 e a mediana é: 1950.0

# %% [markdown]
# ## 4. Moda
#
# A moda é o valor que mais se repete.
#
# ### Exemplos
#
# - Dados: 2, 3, 3, 5, 8
#   Moda = 3
#
# - Dados: azul, azul, verde, vermelho, azul
#   Moda = azul
#
# A moda é a única das medidas de tendência central que pode ser aplicada facilmente também em dados qualitativos.
#
# ### Observações importantes
# - um conjunto pode ter **uma moda**: unimodal
# - pode ter **duas modas**: bimodal
# - pode ter **mais de duas modas**: multimodal
# - pode **não ter moda**, se nenhum valor repetir

# %%
from collections import Counter # valor quantas vezes ele se repete

dados = [2,4,4,8,8,6,6,10,4]
contagem = Counter(dados)
contagem
# Out:
# Counter({2: 1, 4: 3, 8: 2, 6: 2, 10: 1})

# %%
contagem.most_common(1)
# Out:
# [(4, 3)]

# %%
dados2 = [2,3,3,5,8]
dados3 = [2,3,3,5,8,5]
moda = statistics.mode(dados)
moda
# Out:
# 4

# %%
moda3 = statistics.mode(dados3)
moda3
# Out:
# 3

# %%
moda4 = statistics.multimode(dados2)
moda4
# Out:
# [3]

# %% [markdown]
# ### Exemplo de moda em dados qualitativos
# Categorias de produto:
# - eletrônico
# - eletrônico
# - acessório
# - acessório
# - acessório
#
# Moda = acessório

# %%
lista_str = ['acessorio','eletronico','acessorio','eletronico','acessorio']

moda_str = statistics.multimode(lista_str)
moda_str
# Out:
# ['acessorio']

# %% [markdown]
# ## 5. Média ponderada
#
# Na média simples, todos os valores têm o mesmo peso.
#
# Na média ponderada, alguns valores valem mais do que outros.
#
# ### Fórmula
#
# $$
# \text{média ponderada} = \frac{x_1p_1 + x_2p_2 + x_3p_3 + \dots + x_np_n}{p_1+p_2+p_3+\dots+p_n}
# $$
#
# onde:
# - \(x\) são os valores
# - \(p\) são os pesos
#
# ### Exemplo 1: notas com pesos diferentes
# Um aluno tirou:
# - Prova 1 = 7, peso 2
# - Prova 2 = 9, peso 3
#
# $$
# \text{média ponderada} = \frac{7 \cdot 2 + 9 \cdot 3}{2+3}
# = \frac{14+27}{5}
# = \frac{41}{5}
# = 8,2
# $$
#
# Logo, a média ponderada é 8,2.

# %%
notas = [7, 9]
pesos = [2, 3]

media_ponderada = sum(n*p for n, p in zip(notas, pesos)) / sum(pesos)
media_ponderada
# Out:
# 8.2

# %%
import numpy as np

notas = [7, 9]
pesos = [2, 3]

media_ponderada = np.average(notas, weights=pesos)
print(media_ponderada)
# Out:
# 8.2

# %%
import statistics

# Cria uma lista onde o 7 aparece 2 vezes e o 9 aparece 3 vezes
dados_expandidos = [7, 7, 9, 9, 9]
media = statistics.mean(dados_expandidos)

#Aqui tem uma observação importante

# %% [markdown]
# ### Exemplo 2: média ponderada em compras
# Um produto foi vendido assim:
# - 10 unidades a R\$ 5
# - 30 unidades a R\$ 8
#
# O preço médio ponderado por quantidade é:
#
# $$
# \frac{10 \cdot 5 + 30 \cdot 8}{10+30}
# =
# \frac{50+240}{40}
# =
# \frac{290}{40}
# =
# 7,25
# $$
#
# O valor 7,25 representa melhor o preço médio real das vendas do que uma média simples entre 5 e 8.

# %%
precos = [5, 8]
quantidades = [10, 30]

sum(p*q for p, q in zip(precos, quantidades)) / sum(quantidades)
# Out:
# 7.25

# %% [markdown]
# ## 6. Comparando as medidas
#
# | Medida | Ideia principal | Ponto forte | Limitação |
# |---|---|---|---|
# | Média | equilíbrio dos dados | usa todos os valores | sensível a extremos |
# | Mediana | valor central | resiste a outliers | não usa a intensidade completa dos dados |
# | Moda | valor mais frequente | útil em categorias | pode não existir ou haver várias |
# | Média ponderada | média com pesos diferentes | mais realista em muitos contextos | exige pesos corretos |
#
# ### Regra prática
# - use **média** quando os dados forem relativamente equilibrados
# - use **mediana** quando houver valores extremos
# - use **moda** para descobrir o valor mais comum
# - use **média ponderada** quando os valores tiverem importâncias diferentes

# %% [markdown]
# ## 7. Efeito dos valores extremos
#
# Vamos comparar dois conjuntos:
#
# ### Conjunto A
# 10, 12, 13, 14, 16
#
# ### Conjunto B
# 10, 12, 13, 14, 100
#
# Ambos têm vários valores parecidos, mas o segundo tem um valor extremo.

# %%
conjunto_a = [10, 12, 13, 14, 16]
conjunto_b = [10, 12, 13, 14, 100]

resultado = {
    "media_A": sum(conjunto_a)/len(conjunto_a),
    "mediana_A": np.median(conjunto_a),
    "media_B": sum(conjunto_b)/len(conjunto_b),
    "mediana_B": np.median(conjunto_b),
}
resultado
# Out:
# {'media_A': 13.0,
#  'mediana_A': np.float64(13.0),
#  'media_B': 29.8,
#  'mediana_B': np.float64(13.0)}

# %% [markdown]
# ### Conclusão
# No conjunto B, a média sobe bastante por causa do valor 100, mas a mediana permanece mais estável.
#
# Isso mostra por que a mediana é tão importante em dados com outliers.

# %% [markdown]
# ## 8. Aplicações em IA e análise de dados
#
# Essas medidas aparecem em várias tarefas:
#
# ### Média
# - média de notas
# - média de vendas
# - média de tempo de atendimento
# - média de erro de um modelo
#
# ### Mediana
# - valor típico quando há outliers
# - análise de salários
# - tempo de resposta de sistemas
# - limpeza de dados
#
# ### Moda
# - categoria mais frequente
# - classe mais comum
# - produto mais vendido
# - valor usado em preenchimento de dados categóricos faltantes
#
# ### Média ponderada
# - nota final com pesos
# - indicadores compostos
# - métricas combinadas
# - média de preços por volume

# %% [markdown]
# # Exercícios resolvidos
#
# ## Exercício resolvido 1
# Calcule a média de 4, 6, 8, 10
#
# $$
# \text{média} = \frac{4+6+8+10}{4} = \frac{28}{4} = 7
# $$

# %%
dados = [4, 6, 8, 10]
sum(dados)/len(dados)
# Out:
# 7.0

# %% [markdown]
# ## Exercício resolvido 2
# Calcule a mediana de 2, 5, 7, 9, 12
#
# Os dados já estão em ordem.
# O valor central é 7.
# Logo, a mediana é 7.

# %%
np.median([2, 5, 7, 9, 12])
# Out:
# np.float64(7.0)

# %% [markdown]
# ## Exercício resolvido 3
# Calcule a moda de 1, 2, 2, 3, 4, 4, 4, 5
#
# O valor que mais repete é 4.
# Logo, a moda é 4.

# %% [markdown]
# ## Exercício resolvido 4
# Calcule a média ponderada:
# - 6 com peso 1
# - 8 com peso 2
# - 10 com peso 3
#
# $$
# \frac{6\cdot1 + 8\cdot2 + 10\cdot3}{1+2+3}
# =
# \frac{6+16+30}{6}
# =
# \frac{52}{6}
# =
# 8,67
# $$

# %%
valores = [6, 8, 10]
pesos = [1, 2, 3]

sum(v*p for v, p in zip(valores, pesos)) / sum(pesos)
# Out:
# 8.666666666666666

# %% [markdown]
# # Lista de exercícios
#
# ## Parte A – Conceituação
#
# ### Exercício 1
# Explique, com suas palavras:
# - o que é média
# - o que é mediana
# - o que é moda
# - o que é média ponderada
#
# ### Exercício 2
# Qual medida de tendência central costuma ser mais afetada por valores extremos? Explique.
#
# ### Exercício 3
# Em que situação a moda é mais útil do que a média?
#
# ### Exercício 4
# Qual a diferença entre média simples e média ponderada?

# %%
# media --> valor obtido pela soma de todos os dados de um conjunto, dividida pelo número total de elementos
# mediana --> valor que divide um conjunto de dados ordenados (crescente ou decrescente) exatamente ao meio
# moda --> valor (ou valores) que ocorre com maior frequência em um conjunto de dados
# média ponderada --> tipo de média onde cada valor possui um "peso" (importância) diferente associado a ele

# %%
# a média, pois ela considera o valor absoluto de cada elemento na soma, um número muito alto ou muito baixo em relação ao restante do conjunto puxa o resultado da média para cima ou para baixo

# %%
# útil em situações que envolvem dados categóricos (não numéricos) ou quando se quer saber o valor mais frequente em uma distribuição irregular

# %%
# média simples --> todos os elementos do conjunto têm o mesmo peso ou importância
# cada elemento pode possuir unm "peso" diferente

# %% [markdown]
# ## Parte B – Cálculo direto
#
# ### Exercício 5
# Calcule a média:
# - 5, 7, 9
#
# ### Exercício 6
# Calcule a média:
# - 12, 15, 18, 21
#
# ### Exercício 7
# Calcule a mediana:
# - 3, 5, 8, 10, 12
#
# ### Exercício 8
# Calcule a mediana:
# - 4, 6, 8, 10
#
# ### Exercício 9
# Calcule a moda:
# - 2, 2, 3, 4, 5
#
# ### Exercício 10
# Calcule a moda:
# - 1, 3, 3, 4, 4, 6
#
# ### Exercício 11
# Calcule média, mediana e moda:
# - 2, 4, 4, 5, 7
#
# ### Exercício 12
# Calcule média, mediana e moda:
# - 10, 10, 12, 15, 20

# %%
dados1= [5, 7, 9]
media = sum(dados1)/len(dados1)
media
# Out:
# 7.0

# %%
dados2 = [12, 15, 18, 21]
media = sum(dados2)/len(dados2)
media
# Out:
# 16.5

# %%
np.median([3, 5, 8, 10, 12])
# Out:
# np.float64(8.0)

# %%
np.median([4, 6, 8, 10])
# Out:
# np.float64(7.0)

# %%
num = [2, 2, 3, 4, 5]
moda = statistics.mode(num)
moda
# Out:
# 2

# %%
num2 = [1, 3, 3, 4, 4, 6]
moda2 = statistics.multimode(num2)
moda2
# Out:
# [3, 4]

# %%
dados3 = [2, 4, 4, 5, 7]
media = sum(dados3)/len(dados3)

mediana = np.median(dados3)

moda = statistics.mode(dados3)
print(f"A média é: {media}\nA mediana é: {mediana}\nA moda é: {moda}")
# Out:
# A média é: 4.4
# A mediana é: 4.0
# A moda é: 4

# %%
dados4 = [10, 10, 12, 15, 20]
media = sum(dados4)/len(dados4)

mediana = np.median(dados4)

moda = statistics.mode(dados4)
print(f"A média é: {media}\nA mediana é: {mediana}\nA moda é: {moda}")
# Out:
# A média é: 13.4
# A mediana é: 12.0
# A moda é: 10

# %% [markdown]
# ## Parte C – Média ponderada
#
# ### Exercício 13
# Calcule a média ponderada:
# - 7 com peso 2
# - 9 com peso 3
#
# ### Exercício 14
# Calcule a média ponderada:
# - 5 com peso 1
# - 6 com peso 2
# - 8 com peso 2
#
# ### Exercício 15
# Um aluno teve as seguintes notas:
# - trabalho = 8, peso 2
# - prova = 6, peso 5
# - projeto = 9, peso 3
#
# Calcule a média final.
#
# ### Exercício 16
# Um produto foi vendido assim:
# - 20 unidades a R$ 4
# - 10 unidades a R$ 6
# - 30 unidades a R$ 5
#
# Calcule o preço médio ponderado.

# %%
pesos = [7,9]
quantidades = [2,3]

sum(p*q for p, q in zip(pesos, quantidades)) / sum(quantidades)
# Out:
# 8.2

# %%
pesos2 = [5,6,8]
quantidades2 = [1,2,2]

sum(p*q for p, q in zip(pesos2, quantidades2)) / sum(quantidades2)
# Out:
# 6.6

# %%
nota = [8,6,9]
peso = [2,5,3]

media_final = sum(p*q for p, q in zip(nota, peso)) / sum(peso)
media_final
# Out:
# 7.3

# %%
qtd = [20,30,10]
valor = [4,5,6]

sum(p*q for p, q in zip(qtd, valor)) / sum(qtd)
# Out:
# 4.833333333333333

# %% [markdown]
# ## Parte D – Interpretação
#
# ### Exercício 17
# Observe os conjuntos:
# - A = 8, 9, 10, 10, 11
# - B = 8, 9, 10, 10, 100
#
# Calcule a média e a mediana de cada um.
# Depois, diga qual medida representa melhor cada conjunto.
#
# ### Exercício 18
# Uma loja registrou as categorias mais vendidas:
# - camiseta
# - camiseta
# - tênis
# - calça
# - camiseta
# - tênis
#
# Qual é a moda?
# Por que a média não faria sentido aqui?
#
# ### Exercício 19
# Explique por que a mediana pode ser melhor que a média em salários.
#
# ### Exercício 20
# Explique por que a média ponderada é mais adequada para calcular nota final quando provas têm pesos diferentes.

# %%
conjunto_A = [ 8, 9, 10, 10, 11]
conjunto_B = [ 8, 9, 10, 10, 100]

resultado = {
    "media_A": sum(conjunto_A)/len(conjunto_A),
    "mediana_A": np.median(conjunto_A),
    "media_B": sum(conjunto_B)/len(conjunto_B),
    "mediana_B": np.median(conjunto_B),
}
resultado
# Out:
# {'media_A': 9.6,
#  'mediana_A': np.float64(10.0),
#  'media_B': 27.4,
#  'mediana_B': np.float64(10.0)}

# %%
produto = ['camiseta','camiseta','tenis','calca','camiseta','tenis']
moda_str = statistics.multimode(produto)
moda_str
# a média não faz sentido porque é string
# Out:
# ['camiseta']

# %%
"""
mediana é frequentemente superior à média para analisar salários
porque não é distorcida por valores extremos
"""
# Out:
# '\nmediana é frequentemente superior à média para analisar salários \nporque não é distorcida por valores extremos\n'

# %%
"""
média ponderada é mais adequada porque atribui importância proporcional (peso)
a cada avaliação
"""
# Out:
# '\nmédia ponderada é mais adequada porque atribui importância proporcional (peso) \na cada avaliação\n'

# %% [markdown]
# ## Parte E – Aplicação com Python
#
# Execute as células abaixo e complete as respostas.

# %%
# Base 1
notas_turma = [6, 7, 8, 8, 9, 10, 5, 8]

media = sum(notas_turma) / len(notas_turma)
mediana = np.median(notas_turma)
moda = Counter(notas_turma).most_common(1)[0][0]

media, mediana, moda
# Out:
# (7.625, np.float64(8.0), 8)

# %% [markdown]
# ### Exercício 21
# Anote os valores de média, mediana e moda da turma acima.
#
# ### Exercício 22
# Qual medida parece representar melhor essa turma? Explique.

# %%
# média, pois as notas possuem o mesmo peso ou importância

# %%
# Base 2
salarios = [1800, 2000, 2200, 2500, 3000, 50000]

media = sum(salarios) / len(salarios)
mediana = np.median(salarios)

media, mediana
# Out:
# (10250.0, np.float64(2350.0))

# %%
# mediana, pois os valores são muito distantes

# %% [markdown]
# ### Exercício 23
# Compare média e mediana dos salários.
#
# ### Exercício 24
# Qual delas representa melhor o "salário típico" desse grupo?

# %%
# a mediana

# %%
# Base 3
valores = [7, 9, 6]
pesos = [2, 5, 3]

media_pond = sum(v*p for v, p in zip(valores, pesos)) / sum(pesos)
media_pond
# Out:
# 7.7

# %% [markdown]
# ### Exercício 25
# Interprete o valor encontrado acima.
#
# ### Exercício 26
# Se todos os pesos fossem iguais, o resultado mudaria? Verifique.

# %%
# cada valor possui um peso diferente

# %%
valores = [7, 9, 6]
pesos = [6,6,6]

media_pond = sum(v*p for v, p in zip(valores, pesos)) / sum(pesos)
media_pond
# Out:
# 7.333333333333333

# %%
media = sum(valores)/len(valores)
media
# Out:
# 7.333333333333333

# %%
# seria como fazer a média normal, porque ela possui os pesos todos iguais

# %%
# Compare média simples e média ponderada
valores = [7, 9, 6]
media_simples = sum(valores) / len(valores)

pesos = [2, 5, 3]
media_ponderada = sum(v*p for v, p in zip(valores, pesos)) / sum(pesos)

media_simples, media_ponderada
# Out:
# (7.333333333333333, 7.7)

# %% [markdown]
# # Desafio final
#
# Uma escola quer resumir o desempenho de uma turma.
#
# As notas foram:
# - 4, 5, 5, 6, 6, 6, 7, 8, 20
#
# ## Tarefas
# 1. Calcule a média
# 2. Calcule a mediana
# 3. Calcule a moda
# 4. Diga qual medida representa melhor a turma
# 5. Explique por que uma delas pode ser enganosa nesse caso
#
# Depois, responda:
#
# > Se você fosse construir um sistema para analisar automaticamente notas de turmas, qual medida usaria com mais cuidado: média, mediana ou moda? Justifique.

# %%
notas = [4, 5, 5, 6, 6, 6, 7, 8, 20]

media = sum(notas) / len(notas)
mediana = np.median(notas)
moda = statistics.multimode(notas)

media, mediana, moda
# Out:
# (7.444444444444445, np.float64(6.0), [6])

# %% [markdown]
# # Fechamento
#
# Nesta aula, estudamos:
# - média
# - mediana
# - moda
# - média ponderada
#
# Também vimos:
# - quando usar cada medida
# - como valores extremos afetam a média
# - por que a mediana pode ser mais adequada em certos contextos
# - como a média ponderada aparece em notas, vendas e indicadores
#
# Na próxima etapa, essas medidas servirão de base para interpretação de dados e comparação entre grupos.
