# %% [markdown]
# <a href="https://colab.research.google.com/github/camis08/IA_UC4/blob/main/UC4_Aula3_quartis_amplitude.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula – Quartis e Amplitude
#
# ## UC4 – Estatística aplicada à Inteligência Artificial
#
# ### Objetivos
# - Entender profundamente quartis (Q1, Q2, Q3)
# - Compreender amplitude como medida de dispersão
# - Interpretar distribuição de dados
# - Aplicar conceitos em problemas reais e IA

# %% [markdown]
# ## 1. Revisão rápida
#
# Até agora aprendemos:
# - média
# - mediana
# - moda
#
# Essas medidas mostram o "centro" dos dados.
#
# Agora vamos estudar:
# > como os dados estão espalhados

# %% [markdown]
# ## 2. Amplitude
#
# Amplitude = maior valor - menor valor
#
# ### Interpretação
# - amplitude pequena → dados próximos
# - amplitude grande → dados espalhados

# %%
dados = [10, 15, 20, 25, 30,35]

# %%
max(dados)-min(dados)
# Out:
# 25

# %% [markdown]
# Calculando amplitude com Numpy

# %%
import numpy as np
#precisa trasformar a lista em array

np.ptp(np.array(dados))
# Out:
# np.int64(25)

# %%
amplitude = np.max(dados) - np.min(dados)
print(amplitude)
# Out:
# 25

# %%
amplitude = np.ptp(np.array(dados))
amplitude
# Out:
# np.int64(25)

# %%
#print do numpy
int(amplitude)
# Out:
# 25

# %% [markdown]
# ## Exemplo com outlier
#
# Dados:
# 10, 12, 13, 14, 100
#
# Amplitude = 100 - 10 = 90
#
# Isso mostra alta dispersão.

# %%
dados2 = [10, 12, 13, 14, 100]

amplitude = np.ptp(np.array(dados2))
int(amplitude)
# Out:
# 90

# %% [markdown]
# ## 3. Quartis
# *  valores que dividem um conjunto de dados ordenados em quatro partes iguais, cada uma representando 25% da amostra
#
#
#
# **Quartis dividem os dados em 4 partes iguais:**
#
# - Q1 → 25%
# - Q2 → 50% (mediana)
# - Q3 → 75%

# %%
import numpy as np
idades  = [17,20,22,24,36,43,50,55,60,65]
np.percentile(idades,[25,50,75])
# Out:
# array([22.5 , 39.5 , 53.75])

# %% [markdown]
# ## Como calcular manualmente
#
# 1. Ordenar os dados
# 2. Encontrar a mediana (Q2)
# 3. Separar em duas partes
# 4. Calcular mediana de cada parte (Q1 e Q3)

# %%
"""
[17,20,22,24,36|43,50,55,60,65]
Q2 = 36+44/2 = 80/2 = 40

Q1 = 22

Q3 = 55
"""
# Out:
# '\n[17,20,22,24,36|43,50,55,60,65]\nQ2 = 36+44/2 = 80/2 = 40\n\nQ1 = 22\n\nQ3 = 55\n'

# %% [markdown]
# ## Exemplo detalhado
#
# Dados:
# 5, 10, 15, 20, 25
#
# Vamos calcular juntos

# %%
import numpy as np
idades  = [17,20,22,24,36,43,50,55,60,65]
np.percentile(idades,[25,50,75])
# Out:
# array([22.5 , 39.5 , 53.75])

# %%
dados  = [5, 10, 15, 20, 25]
np.percentile(dados,[25])
# Out:
# array([10.])

# %% [markdown]
# ## 4. Interpretação dos quartis
#
# - 25% dos dados estão abaixo de Q1
# - 50% dos dados estão abaixo de Q2
# - 75% dos dados estão abaixo de Q3
#
# Isso ajuda a entender distribuição.

# %%
# O método 'inverted_cdf' costuma aproximar de cálculos manuais simples

# %% [markdown]
# ## 5. Aplicações reais
#
# ### Exemplo: salários
# Quartis ajudam a identificar:
# - salário baixo (Q1)
# - salário típico (Q2)
# - salários altos (Q3)
#
# ### Em IA
# - detecção de outliers
# - normalização
# - análise exploratória

# %%
# salarios = [1500, 1800, 2000 |2200| 2500, 3000, 10000]
    # 1500 |1800| 2000, 2200, 2500, 3000, 10000]
        # 1500, 1800, 2000, 2200, 2500 |3000| 10000]

"""
Q2 = 2200

Q1 = 1800

Q3 = 3000

"""
salarios = [1500, 1800, 2000 ,2200, 2500, 3000, 10000]
np.percentile(salarios,[25,50,75])
# Out:
# array([1900., 2200., 2750.])

# %%
q1,q2,q3 = np.percentile(salarios,[25,50,75])
print(f"Q1: {q1}")
print(f"Q2: {q2}")
print(f"Q3: {q3}")
# Out:
# Q1: 1900.0
# Q2: 2200.0
# Q3: 2750.0

# %%
int(q1)
# Out:
# 1900

# %%
int(q2)
# Out:
# 2200

# %%
int(q3)
# Out:
# 2750

# %% [markdown]
# ### A beleza do boxplot

# %%
import seaborn as sns
sns.boxplot(x=salarios)
# Out:
# <Axes: >

# %%
salarios2 = [1500, 1800, 2000 ,2200, 2500, 3000,3500]
np.percentile(salarios2,[25,50,75])
sns.boxplot(salarios2)
# Out:
# <Axes: >

# %% [markdown]
# Método NumPy (Linear): Usa a fórmula $$i= (n-1) \cdot P$$, onde:
# - n é o número de elementos;
# - p é o percentil desajado (0.25 para **Q1**, 0.50 para **Q2**, 0.75 para **Q3**)

# %% [markdown]
# # Interpretação de Quartis
#
# ---
#
# ## O que os quartis nos mostram?
#
# Os quartis ajudam a responder:
#
# > Como os dados estão distribuídos?
#
# Eles dividem os dados em 4 partes:
#
# - Q1 → 25% dos dados estão abaixo desse valor
# - Q2 → 50% dos dados (mediana)
# - Q3 → 75% dos dados
#
# ---

# %% [markdown]
# ## O que observar na análise
#
# ### 1. Concentração dos dados
#
# Observe os intervalos:
#
# - mínimo → Q1
# - Q1 → Q2
# - Q2 → Q3
# - Q3 → máximo
#
# Regra:
#
# - Intervalo pequeno → dados concentrados
# - Intervalo grande → dados espalhados
#
# ---
#
# ### 2. Assimetria dos dados
#
# Compare:
#
# - distância entre Q1 e Q2
# - distância entre Q2 e Q3
#
# Interpretação:
#
# - Distâncias parecidas → dados equilibrados
# - Um lado maior → dados inclinados (assimétricos)
#
# Exemplo:
#
# Q1 = 10
# Q2 = 12
# Q3 = 30
#
# → dados puxados para valores maiores
#
# ---
#
# ### 3. Presença de outliers
#
# Observe:
#
# - distância entre Q3 e o valor máximo
# - distância entre o valor mínimo e Q1
#
# Se houver grande diferença:
#
# → possível presença de valores extremos (outliers)
#
# ---
#
# ### 4. Variabilidade dos dados
#
# Use o intervalo interquartil (IQR):
#
# IQR = Q3 - Q1
#
# Interpretação:
#
# - IQR pequeno → dados homogêneos
# - IQR grande → dados muito variados

# %% [markdown]
# ---
#
# ## O que podemos concluir com quartis
#
# ### Exemplo 1 – Dados concentrados
#
# Q1 = 10
# Q2 = 12
# Q3 = 14
#
# Conclusões:
#
# - dados próximos
# - baixa variação
# - comportamento consistente
#
# ---
#
# ### Exemplo 2 – Dados espalhados
#
# Q1 = 10
# Q2 = 20
# Q3 = 50
#
# Conclusões:
#
# - alta variabilidade
# - dados muito diferentes entre si
# - comportamento instável
#
# ---
#
# ### Exemplo 3 – Presença de outlier
#
# Q1 = 10
# Q2 = 12
# Q3 = 14
# máximo = 100
#
# Conclusões:
#
# - existe valor extremo
# - média pode estar distorcida
# - mediana é mais confiável
#
# ---
#
# ## Aplicação em Inteligência Artificial
#
# Quartis são utilizados para:
#
# - detectar outliers
# - limpar dados
# - entender a distribuição
# - preparar dados para modelos
# - criar faixas de classificação (baixo, médio, alto)
#
# ---
#
# ## Resumo
#
# Ao analisar quartis, observe:
#
# - concentração dos dados
# - assimetria
# - presença de outliers
# - tamanho do IQR
#
# Essas informações ajudam a entender o comportamento dos dados e tomar decisões mais confiáveis.

# %% [markdown]
# ----

# %% [markdown]
# # Exercícios – Parte 1 (básico)
#
# 1. Calcule a amplitude:
# [5, 10, 15, 20]
#
# 2. Calcule a amplitude:
# [100, 120, 150, 300]
#
# 3. Calcule Q1, Q2 e Q3:
# [10, 20, 30, 40, 50]

# %%
dados = [5, 10, 15, 20]
amplitude = max(dados)-min(dados)
print(f"Amplitude --> {amplitude}")
# Out:
# Amplitude --> 15

# %%
dados2 = [100, 120, 150, 300]
amplitude2 = max(dados2)-min(dados2)
print(f"Amplitude --> {amplitude2}")
# Out:
# Amplitude --> 200

# %%
num = [10, 20, 30, 40, 50]
q1,q2,q3 = np.percentile(num,[25,50,75])
print(f"Q1: {q1}")
print(f"Q2: {q2}")
print(f"Q3: {q3}")
# Out:
# Q1: 20.0
# Q2: 30.0
# Q3: 40.0

# %% [markdown]
# # Exercícios – Parte 2 (intermediário)
#
# 4. Dados:
# [3, 5, 7, 9, 11, 13, 15]
#
# Calcule:
# - amplitude
# - quartis
#
# 5. Dados:
# [10, 12, 14, 16, 18, 20]
#
# Calcule quartis manualmente.

# %%
dados3 =  [3, 5, 7, 9, 11, 13, 15]
amplitude = max(dados3)-min(dados3)
print(f"Amplitude --> {amplitude}")

q1,q2,q3 = np.percentile(dados3,[25,50,75])
print(f"Q1: {q1}")
print(f"Q2: {q2}")
print(f"Q3: {q3}")
# Out:
# Amplitude --> 12
# Q1: 6.0
# Q2: 9.0
# Q3: 12.0

# %% [markdown]
# # Exercícios – Parte 3 (interpretação)
#
# 6. Dados:
# [10, 12, 13, 14, 100]
#
# - Qual a amplitude?
# - Existe outlier?
# - Quartis ajudam a entender isso?
#
# 7. Compare:
# A = [10, 12, 14, 16, 18]
# B = [10, 12, 14, 16, 100]
#
# Qual tem maior dispersão?

# %%
dados4 =  [10, 12, 13, 14, 100]
amplitude = max(dados4)-min(dados4)
print(f"Amplitude --> {amplitude}")

q1,q2,q3 = np.percentile(dados4,[25,50,75])
print(f"Q1: {q1}")
print(f"Q2: {q2}")
print(f"Q3: {q3}")
# Out:
# Amplitude --> 90
# Q1: 12.0
# Q2: 13.0
# Q3: 14.0

# %%
#sim, o 100

# %%
sns.boxplot(x= dados4)
# Out:
# <Axes: >

# %%
A = [10, 12, 14, 16, 18]
amplitude_a = max(A)-min(A)
print(f"Amplitude A--> {amplitude_a}")

B = [10, 12, 14, 16, 100]
amplitude_b = max(B)-min(B)
print(f"Amplitude B--> {amplitude_b}")
# Out:
# Amplitude A--> 8
# Amplitude B--> 90

# %%
# B possui maior dispersão

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(x= A, ax=axes[0])
sns.boxplot(x= B, ax=axes[1])

plt.tight_layout()
plt.show()

# %%
dados = [A, B]

plt.figure(figsize=(8, 5))
sns.boxplot(data=dados)

plt.xticks([0, 1], ["Conjunto A", "Conjunto B"])
plt.title("Comparação de Dispersão (Boxplot)")
plt.ylabel("Valores")

plt.show()

# %% [markdown]
# # Exercícios – Parte 4 (Python)
#
# Use Python para resolver:
#
# 8. Dados:
# [8, 9, 10, 11, 12, 13, 50]
#
# Calcule quartis e amplitude.
#
# 9. Dados:
# [2, 4, 6, 8, 10, 12, 14]
#
# Calcule quartis.

# %%
dados5 = [8, 9, 10, 11, 12, 13, 50]
amplitude = max(dados5)-min(dados5)
print(f"Amplitude --> {amplitude}")

q1,q2,q3 = np.percentile(dados5,[25,50,75])
print(f"Q1: {q1}")
print(f"Q2: {q2}")
print(f"Q3: {q3}")
# Out:
# Amplitude --> 42
# Q1: 9.5
# Q2: 11.0
# Q3: 12.5

# %% [markdown]
# # Desafio final
#
# Dados:
# [2000, 2200, 2500, 2700, 3000, 3500, 10000]
#
# 1. Calcule amplitude
# 2. Calcule quartis
# 3. Interprete
# 4. Identifique outlier

# %%
dados5 = [2000, 2200, 2500, 2700, 3000, 3500, 10000]

amplitude = max(dados5)-min(dados5)
print(f"Amplitude --> {amplitude}")

q1,q2,q3 = np.percentile(dados5,[25,50,75])
print(f"Q1: {q1}")
print(f"Q2: {q2}")
print(f"Q3: {q3}")
# Out:
# Amplitude --> 8000
# Q1: 2350.0
# Q2: 2700.0
# Q3: 3250.0

# %%
#8000 é o Outliner

# %% [markdown]
# # Exercício – Interpretação de Quartis
#
# ---
#
# ## Situação
#
# Uma empresa analisou o salário de seus funcionários e obteve os seguintes dados (em reais):
#
# [1500, 1800, 2000, 2200, 2500, 2800, 3000, 3500, 10000]
#
# ---
#
# ## Etapa 1 – Cálculo
#
# 1. Ordene os dados (se necessário)
# 2. Calcule:
#    - Q1
#    - Q2 (mediana)
#    - Q3
# 3. Calcule a amplitude

# %%
salario_ = [1500, 1800, 2000, 2200, 2500, 2800, 3000, 3500, 10000]
amplitude = max(salario_)-min(salario_)
print(f"Amplitude --> {amplitude}")

q1,q2,q3 = np.percentile(salario_,[25,50,75])
print(f"Q1: {q1}")
print(f"Q2: {q2}")
print(f"Q3: {q3}")
# Out:
# Amplitude --> 8500
# Q1: 2000.0
# Q2: 2500.0
# Q3: 3000.0

# %% [markdown]
# ---
#
# ## Etapa 2 – Interpretação
#
# Responda:
#
# ### 1. Concentração dos dados
# - Entre quais quartis os dados estão mais concentrados?
# - Existe algum intervalo muito maior que os outros?
#
# ---
#
# ### 2. Assimetria
# - Os dados estão equilibrados ou puxados para um lado?
# - Se estiverem puxados, para qual lado?
#
# ---
#
# ### 3. Outliers
# - Existe algum valor que parece fora do padrão?
# - Qual é esse valor?
# - Como ele impacta a análise?
#
# ---
#
# ### 4. Variabilidade
# - O intervalo entre Q1 e Q3 é grande ou pequeno?
# - O que isso indica sobre os salários?
#
# ---
#
# ### 5. Tomada de decisão
# Se você fosse um gestor, responda:
#
# - A maioria dos funcionários ganha salários próximos ou muito diferentes?
# - A média seria uma boa medida para representar esses dados? Por quê?
# - Qual medida você usaria para representar o “salário típico”?

# %%
"""
Entre quais quartis os dados estão mais concentrados?
Existe algum intervalo muito maior que os outros?
"""
# entre Q1 e Q3
# sim, entre o Q1 e o Q3 1000, mas entre Q1 e Q2 500, Q2 e Q3 500 também
# Out:
# '\nEntre quais quartis os dados estão mais concentrados?\nExiste algum intervalo muito maior que os outros?\n'

# %%
# equilibrados
# os dados estão puxados para a direita (assimetria positiva)

# %%
# sim
# 10000
# dá a impressão de que os salários são maiores do que realmente são

# %%
sns.boxplot(x= salario_)
# Out:
# <Axes: >

# %%
# é pequeno, apenas de 1000
# significa que a maioria dos salários está bem concentrada

# %% [markdown]
# ---
#
# ## Etapa 3 – Reflexão (nível IA)
#
# Imagine que você está treinando um modelo de IA com esses dados.
#
# - Esse valor extremo (10000) pode atrapalhar o modelo?
# - Você removeria esse valor? Por quê?
# - Como os quartis ajudam na limpeza dos dados?
#
# ---
#
# ## Desafio bônus
#
# Compare com o conjunto abaixo:
#
# [1500, 1800, 2000, 2200, 2500, 2800, 3000, 3500]
#
# - O que mudou na análise?
# - Qual conjunto é mais confiável para representar a realidade?
#
# ---
#
# ## Objetivo do exercício
#
# Este exercício tem como objetivo desenvolver a capacidade de:
#
# - interpretar quartis
# - analisar distribuição de dados
# - identificar outliers
# - tomar decisões com base em dados

# %% [markdown]
# ---
#
# ## Desafio bônus
#
# Compare com o conjunto abaixo:
#
# [1500, 1800, 2000, 2200, 2500, 2800, 3000, 3500]
#
# - O que mudou na análise?
# - Qual conjunto é mais confiável para representar a realidade?
#
# ---
#
# ## Objetivo do exercício
#
# Este exercício tem como objetivo desenvolver a capacidade de:
#
# - interpretar quartis
# - analisar distribuição de dados
# - identificar outliers
# - tomar decisões com base em dados
