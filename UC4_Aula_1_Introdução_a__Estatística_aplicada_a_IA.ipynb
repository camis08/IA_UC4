# %% [markdown]
# <a href="https://colab.research.google.com/github/camis08/IA_UC4/blob/main/UC4_Aula_1_Introdu%C3%A7%C3%A3o_a__Estat%C3%ADstica_aplicada_a_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  UC4 - Estatística aplicada à Inteligência Artificial

# %% [markdown]
# ## Aula 1 - Introdução à Estatística
#
# ---
#
# ###  Objetivo da aula
# - Entender o que é estatística
# - Entender o papel da estatística na IA
# - Classificar tipos de dados
#
# ---
#  **Mensagem importante:**
# > IA não é só código. IA é entender dados.

# %% [markdown]
# # O que é Estatística?
#
# Estatística é a área que trabalha com:
#
# - Coleta de dados
# - Organização de dados
# - Análise de dados
# - Tomada de decisão
#
# ---
#
# ## Exemplos
#
# - Média de notas → aprovação
# - Consumo → recomendação
# - Padrões → detecção de fraude

# %% [markdown]
# O objetivo da estatística é transformar dados em informação para apoiar decisões.
#
# ---
#
# ## Dado x Informação
#
# ### Dado
# É um valor bruto, sem contexto.
#
# Exemplos:
# - 25
# - 3000
# - "DF"

# %% [markdown]
# ### Informação
# É o dado interpretado com significado.
#
# Exemplos:
# - 25 anos de idade
# - salário de 3000 reais
# - mora em São Paulo
#
# ---

# %% [markdown]
# ## População e Amostra
#
# ### População
# É o conjunto total de elementos que queremos estudar.
#
# Exemplo:
# - todos os alunos de uma escola
# - todos os clientes de uma empresa
#
# ---
#
# ### Amostra
# É uma parte da população utilizada para análise. Um subconjunto da populacao
#
# Exemplo:
# - 30 alunos de uma turma
# - 100 clientes selecionados
#
# ---

# %% [markdown]
# ### Tipos de amostragem (o mais importante)
# 1. **Amostragem aleatória simples**
# * *Todos têm a mesma chance de ser escolhidos*
#
# Exemplo:
#
# sortear nomes de uma lista
#
# (É o método mais correto)
#
# ----
# 2. **Amostragem por conveniência**
#
# * *Escolhe quem está mais fácil*
#
# Exemplo:
#
# entrevistar só quem está na sala
#
# Problema: pode gerar viés

# %% [markdown]
# 3. **Amostragem estratificada**
#
# * *Divide a população em grupos e pega um pouco de cada*
#
# Exemplo:
#
# homens e mulheres
# diferentes idades
#
# (Muito usada em pesquisa)
#
# -----
# 4. **Amostragem sistemática**
#
# * *Seleciona de forma regular*
#
# Exemplo:
#
# a cada 10 pessoas, escolhe 1

# %% [markdown]
# # Estatística na Inteligência Artificial
#
# A IA depende da estatística para funcionar.
#
# | Etapa | Uso da estatística |
# |------|------------------|
# | Coleta | Organização de dados |
# | Treinamento | Cálculo de padrões |
# | Avaliação | Medidas de erro |
# | Decisão | Probabilidade |
#
# ---
#
# Sem estatística, a IA não consegue aprender.

# %% [markdown]
# # Tipos de Dados

# %% [markdown]
# ## Variável
#
# Variável é qualquer característica que pode ser observada ou medida.
#
# Exemplos:
# - idade
# - salário
# - cidade
# - nota
#
# ---

# %% [markdown]
# ## Variáveis Qualitativas
#
# - Não são numéricas (ou não fazem sentido calcular)
# - Representam categorias
#
# Ex:
# - Nome
# - Cor
# - Cidade
# - Estado civil
#
# ---
#
# ## Variáveis Quantitativas
#
# - São numéricas
# - Permitem cálculos
#
# Ex:
# - Idade
# - Salário
# - Altura
# - Quantidade

# %% [markdown]
# ## Variáveis Quantitativas (Subtipos)
#
# ###  Discretos
# - Valores inteiros
# - Contáveis
#
# Ex:
# - Número de filhos
# - Número de compras
#
# ---
#
# ###  Contínuos
# - Podem ter qualquer valor
# - Incluem decimais
#
# Ex:
# - Altura
# - Peso
# - Temperatura

# %% [markdown]
# ## Variáveis Qualitativas (Subtipos)
#
# ### Nominais
# - Não possuem ordem
# - - Ex: cor, cidade, gênero
#
# ### Ordinais
# - Possuem ordem
# - - Ex: escolaridade, satisfação, ranking

# %%
# Vamos criar um dataset simples
import pandas as pd

winx = {
    'fadas': ['Bloom', 'Stella', 'Flora', 'Aisha','Tecna','Musa'],
    'idade': [16,17,16,17,16,16],
    'magia': ['chama do dragão','sol e lua','natureza','água','tecnologia','som']
}
df = pd.DataFrame(winx)
df
# Out:
#     fadas  idade            magia
# 0   Bloom     16  chama do dragão
# 1  Stella     17        sol e lua
# 2   Flora     16         natureza
# 3   Aisha     17             água
# 4   Tecna     16       tecnologia
# 5    Musa     16              som

# %%
dados= {
    'abc': ['A','B','C','D'],
    'idade': [26,25,27,28],
    'salario': [2500,3000,4100,1650],
    'cidade': ['RJ','DF','MG','SP']
}
df = pd.DataFrame(dados)
df
# Out:
#   abc  idade  salario cidade
# 0   A     26     2500     RJ
# 1   B     25     3000     DF
# 2   C     27     4100     MG
# 3   D     28     1650     SP

# %% [markdown]
# # Análise
#
# Responda:
#
# 1. Qual coluna é qualitativa?
# 2. Qual coluna é quantitativa?
# 3. Qual coluna representa valores contínuos?
# 4. Qual coluna representa valores quantitativos discretos?
# ---
#
#  Escreva suas respostas abaixo:

# %%
# Resposta
"""
1- ABC e cidade
2- Salário e idade
3- Salário
4- Idade
"""

"""
nome - variável qualitativa nominal
idade - variável quantitativa discreta
salário - variável quantitativa contínua
cidade - variável qualitativa nominal
"""
# Out:
# '\nnome - variável qualitativa nominal\nidade - variável quantitativa discreta\nsalário - variável quantitativa contínua\ncidade - variável qualitativa nominal\n'

# %% [markdown]
# # Exercício 1
#
# Classifique:
#
# | Dado | Tipo |
# |------|-----|
# | Nome | |
# | Idade | |
# | Salário | |
# | Cor favorita | |
# | Número de filhos | |

# %%
"""
1- Qualitativo
2- Quantitativo discreto (apenas valores inteiros e isolados)
3- Quantitativo contínuo ()
"""

"""
nome - qualitativa nominal
idade - quantitativo discreto
salário - quantitativo contínua
cor favorita - qualitativo nominal
num filhos - quantitativo discreto
"""

# %% [markdown]
# # Exercício 2
#
# Classifique como:
#
# - Qualitativo
# - Quantitativo discreto
# - Quantitativo contínuo
#
# | Dado | Tipo |
# |------|-----|
# | Altura | |
# | Número de alunos | |
# | Temperatura | |
# | Salário | |

# %%
# Vamos criar outro dataset para prática
"""
1- Qualitativo
2- Quantitativo discreto (apenas valores inteiros e isolados)
3- Quantitativo contínuo ()
"""

"""
altura - quantitativo contínua
número alunos - quantitativo discreto
temperatura - quantitativa contínuo
salário - quantitativo contínuo
"""

# %% [markdown]
# #  Exercício 3
#
# Classifique cada coluna do dataset acima:
#
# - produto
# - preco
# - quantidade_vendida
# - categoria

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dados2 = {
    'produto': ['arroz','feijão','macarrão'],
    'preco': [16.00,6.50,5.50],
    'qnt_vendas': [20,50,30],
    'categoria' : ['grão','grão','massa']
}
df2 = pd.DataFrame(dados2)
df2
# Out:
#     produto  preco  qnt_vendas categoria
# 0     arroz   16.0          20      grão
# 1    feijão    6.5          50      grão
# 2  macarrão    5.5          30     massa

# %%
"""
1- Qualitativo ( não são números, e sim categorias)
2- Quantitativo discreto (dados numéricos que são contáveis (inteiros))
3- Quantitativo contínuo ()
"""

"""
produto - quantitativo
preço - quantitativo discreto
qnt_vendas - quantitativa contínuo
categoria - quanlitativo nominal

# %%
importante = {
   'Variaveis_Qualitativas': ['Nominal', 'Ordinal'],
   'Variaveis_Quantitativas': ['Discreta', 'Contínua']
   'Variaveis_Quantitativas_Discreta': ['Simples', 'Composta']
}
importante

# %%
import pandas as pd

dados = {
    "Tipo de dado": [
        "Qualitativo",
        "Quantitativo discreto",
        "Quantitativo contínuo"
    ],
    "O que é": [
        "Categoria (não numérico)",
        "Número contável",
        "Número mensurável"
    ],
    "Característica": [
        "Não permite cálculos matemáticos",
        "Valores inteiros",
        "Pode ter valores decimais"
    ],
    "Exemplo": [
        "cor dos olhos, estado civil",
        "nº de alunos, nº de filhos",
        "altura, peso, tempo"
    ]
}

df = pd.DataFrame(dados)
df
# Out:
#             Tipo de dado                   O que é  \
# 0            Qualitativo  Categoria (não numérico)
# 1  Quantitativo discreto           Número contável
# 2  Quantitativo contínuo         Número mensurável
#
#                      Característica                      Exemplo
# 0  Não permite cálculos matemáticos  cor dos olhos, estado civil
# 1                  Valores inteiros   nº de alunos, nº de filhos
# 2         Pode ter valores decimais          altura, peso, tempo

# %%
import pandas as pd

dados = {
    "Categoria": [
        "Definição",
        "Qualitativa",
        "Quantitativa",
        "Quantitativa - Discreta",
        "Quantitativa - Contínua",
        "Qualitativa - Nominal",
        "Qualitativa - Ordinal"
    ],
    "Descrição": [
        "Variável é qualquer característica que pode ser observada ou medida",
        "Não numérica, representa categorias",
        "Numérica, permite cálculos",
        "Valores inteiros e contáveis",
        "Valores contínuos, podem ter decimais",
        "Não possuem ordem",
        "Possuem ordem"
    ],
    "Exemplos": [
        "idade, salário, cidade, nota",
        "nome, cor, cidade, estado civil",
        "idade, salário, altura, quantidade",
        "número de filhos, número de compras",
        "altura, peso, temperatura",
        "cor, cidade, gênero",
        "escolaridade, satisfação, ranking"
    ]
}

df = pd.DataFrame(dados)
df
# Out:
#                  Categoria                                          Descrição  \
# 0                Definição  Variável é qualquer característica que pode se...
# 1              Qualitativa                Não numérica, representa categorias
# 2             Quantitativa                         Numérica, permite cálculos
# 3  Quantitativa - Discreta                       Valores inteiros e contáveis
# 4  Quantitativa - Contínua              Valores contínuos, podem ter decimais
# 5    Qualitativa - Nominal                                  Não possuem ordem
# 6    Qualitativa - Ordinal                                      Possuem ordem
#
#                               Exemplos
# 0         idade, salário, cidade, nota
# 1      nome, cor, cidade, estado civil
# 2   idade, salário, altura, quantidade
# 3  número de filhos, número de compras
# 4            altura, peso, temperatura
# 5                  cor, cidade, gênero
# 6    escolaridade, satisfação, ranking

# %% [markdown]
# ## Reforço

# %% [markdown]
# ###Classifique os dados abaixo:
#
# - CPF --> Qualitativa Nominal
# - Temperatura --> Quantitativo Contínuo
# - Placa de carro --> Qualitativa Nominal
# - Altura --> Quantitativa Continuo
# - Número de curtidas no Instagram --> Quantitativa Discreta
# - CEP --> Qualitativa Nominal
# - Salário --> Quantitativa Contínua
# - Tipo sanguíneo --> Qualitativa Nominal

# %% [markdown]
# ### Se você fosse criar uma IA para recomendar filmes, quais dados você usaria?

# %% [markdown]
# ### Explorando dados no Python
#
# - ´df.info´ e ´df.describe()´

# %% [markdown]
# ### Desafio final

# %%
dados = {
    "idade": [18, 25, 40, 60],
    "compra": ["sim", "sim", "não", "não"]
}

# %% [markdown]
# Se chega uma pessoa com 30 anos, ela compraria?

# %% [markdown]
# “Com base em quê?”
#
# “Achismo ou dados?”

# %% [markdown]
# “Nosso cérebro quer encontrar padrão rápido.
# Mas a estatística exige evidência.”

# %% [markdown]
# “Com poucos dados, a IA também erra.”

# %% [markdown]
# Você pode falar:
#
# “Se tivéssemos MUITOS dados, poderíamos modelar isso”
#
# Exemplo:
#
# regressão (idade vs compra)
# probabilidade condicional
#
# Aí você conecta com IA de verdade

# %% [markdown]
# #  Conclusão
#
# Hoje você aprendeu:
#
# - O que é estatística
# - A importância dela na IA
# - Tipos de dados
# - Discreto vs contínuo
#
# ---
#
#  Na próxima aula:
# Vamos começar a analisar dados de verdade (média, moda, etc).
#
# ---
#
#  Lembre-se:
# > IA começa com entender dados.
